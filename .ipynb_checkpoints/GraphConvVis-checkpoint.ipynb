# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pydot
from networkx.drawing.nx_pydot import write_dot

np.random.seed(0)

# %%
# g = nx.erdos_renyi_graph(8, 0.25)
# while not nx.is_connected(g):
#     g = nx.erdos_renyi_graph(8, 0.25)

# layout = nx.kamada_kawai_layout(g)

# # nx.draw(g, pos=layout)

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
    temp = [np.random.choice([0,1], p=[0.8, 0.2]) for _ in range(6)]
    temp = str(temp)
    temp = temp[:9] + '...' + temp[10:]
    temp = ''.join([x for x in temp if x != ','])
    labels.append('1 x $n$\n' + temp)

x_offs = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
y_offs = [-0.025, 0.025, 0.025, -0.025, 0.025, 0.025, 0.025, -0.025]

for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
colors = []
tar = 5

np.random.seed(0)

for node in g.nodes:
    if node == tar:
        colors.append('red')
    elif node in g[tar]:
        colors.append('orange')
    else:
        colors.append('blue')
    
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color=colors)

x_offs = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
y_offs = [-0.025, 0.025, 0.025, -0.025, 0.025, 0.025, 0.025, -0.025]

for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
#     temp = [np.random.choice([0,1], p=[0.8, 0.2]) for _ in range(6)]
#     temp = str(temp)
#     temp = temp[:9] + '...' + temp[10:]
    temp = '[' + str(np.random.uniform())[1:4] + ' ' + str(np.random.uniform())[1:4] + ' $\ldots$ '  + str(np.random.uniform())[1:4] + ']'
    labels.append('1 x 512\n' + temp)

for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
    t0 = '[[' + str(np.random.uniform())[1:4] + ' ' + str(np.random.uniform())[1:4] + ' $\ldots$]\n'
    t0 = t0 + r'[  $\vdots$  $\ddots$' + '      ]\n'  
    t0 = t0 + '[ ' + str(np.random.uniform())[1:4] + '    ' + str(np.random.uniform())[1:4] + ']]'
    t0 = '16 x 255\n' + t0
    labels.append(t0)
    
for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
    t0 = '[[' + str(np.random.uniform())[1:4] + ' ' + str(np.random.uniform())[1:4] + ' $\ldots$]\n'
    t0 = t0 + r'[  $\vdots$  $\ddots$' + '      ]\n'  
    t0 = t0 + '[ ' + str(np.random.uniform())[1:4] + '    ' + str(np.random.uniform())[1:4] + ']]'
    t0 = '8 x 126\n' + t0
    labels.append(t0)
    
for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
    temp = '[' + str(np.random.uniform())[1:4] + ' ' + str(np.random.uniform())[1:4] + ' $\ldots$ '  + str(np.random.uniform())[1:4] + ']'
    labels.append('1 x 124\n' + temp)

for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')

# %%
fig, ax = plt.subplots(figsize=(10,10))
nx.draw(g, pos=layout, node_color='blue')

labels = []
for i in range(len(g.nodes)):
    temp = '[' + str(np.random.uniform())[1:4] + ' ' + str(np.random.uniform())[1:4] + ' $\ldots$ '  + str(np.random.uniform())[1:4] + ']'
    labels.append('1 x 16\n' + temp)

for i in range(len(layout)):
    x,y=layout[i]
    plt.text(x+x_offs[i],y+y_offs[i],s=labels[i], bbox=dict(facecolor='gray', alpha=0.5),horizontalalignment='left')
